# %% [markdown]
# # 1.0 Introduction to JAX
# Main references:
# - [1] https://github.com/google/jax
#
# - [2] https://colindcarroll.com/2019/04/06/exercises-in-automatic-differentiation-using-autograd-and-jax/
#
# - [3] https://github.com/HIPS/autograd/blob/master/docs/tutorial.md
# - [4] https://colinraffel.com/blog/you-don-t-know-jax.html
# - [5] https://jax.readthedocs.io/en/latest/notebooks/autodiff_cookbook.html
#
#
# *At its core, JAX is an extensible system for transforming numerical functions.* JAX implements an updated version of **autograd**. Autograd's `grad` function takes in a **scalar** function, and returns to you the gradient function.
#
#  In this tutorial we will go through some of the main features included in the JAX package: ```grad``` and ```jit```.
#
#  One of the main features you will probably use during this course is the ```grad``` function for computing gradients of your loss functions with respect to your model's weights.

# %% [markdown]
# ## 1.1 Step-by-step example on how to use ```jax.grad``` for auto-differentiation.
#
# **1) Define your function**
#
# $$y = \sigma(wx + b),\ \sigma(x)=\frac{1}{1+e^{-x}}$$

# %%
import jax.numpy as np
from jax import grad, jit, vmap, random, value_and_grad
import itertools
import time


key = random.PRNGKey(1)

x = random.normal(key)
w = random.normal(key+1)
b = random.normal(key+2)
w0 = w
b0 = b
def sigmoid(x):
    return 1/(1 + np.exp(-x))

#
def make_linear_sigmoid(x):
  def predict(W, b): # Here, you define the function with the parameters that define your model
    return sigmoid(np.dot(x, W) + b)
  return predict

# %% [markdown]
# ## **2) Define your gradient with respect to the fitting weights**
#
#
# The function `grad` takes as arguments:
# -  `fun`: the numpy **function** for which the computation of the gradients is needed.
# - `argnums`: the **arguments** of the functions  with respect to which the function will be differentiated
#
# ```
# grad_not_jit(fun = make_linear_sigmoid(x),
#                               argnums =  (0,1))
#
# ```
# Returns the evaluated **gradients**.
#
#
#
# ---
# **Quick quiz**: what would you change in the code above if you needed to differentiate the function only with respect to $b$?

# %% [markdown]
# **Using jit to speed up functions (VERY IMPORTANT FOR THE FUTURE)**
#
# JAX provides jit (just in time compiler) which takes Python (using numpy) functions and compiles them such that they can be run efficiently on the chosen accelerators (CPU/GPU/TPU). Using jit could significantly speed up your computations and it requires little to no overhead in your coding. Let's have a look at a simple example. It is sufficient to use the jit decorator in front of your function such that the declared operation are compiled in advance (only once) and the code will run much more efficiently without any interpreter overhead.

# %%
# I am ignoring the values returned for timing because of issues with the scoping of functions (timeit issue)
grad_not_jit = grad(make_linear_sigmoid(x), (0,1))
# %timeit _, _ = grad_not_jit(w,b) # AUTOGRAD

grad_jit = jit(grad(make_linear_sigmoid(x), (0,1)))
# %timeit _, _ = grad_jit(w,b) # AUTOGRAD

# Check with the analytical computation
w_gradient , b_gradient = grad_jit(w,b) # AUTOGRAD

w_gradient_manual = sigmoid(np.dot(x, w) + b) * (1 - sigmoid(np.dot(x, w) + b)) * x
b_gradient_manual = sigmoid(np.dot(x, w) + b) * (1 - sigmoid(np.dot(x, w) + b))

print()
print('Autograd result : w')
print(w_gradient)
print('Manually derived result : w')
print(w_gradient_manual)

print('Autograd result : b')
print(b_gradient)
print('Manually derived result : b')
print(b_gradient_manual)
# Out:
# 100 loops, best of 3: 4.13 ms per loop
# The slowest run took 319.44 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 3: 185 µs per loop
#
# Autograd result : w
# -0.26804116
# Manually derived result : w
# -0.2680411
# Autograd result : b
# 0.22633177
# Manually derived result : b
# 0.22633173

# %% [markdown]
# #2.0 Review of Linear Regression
# As studied in your lecture, in linear regression, we are given a data set $\mathcal{D} =  \{(x_n,t_n)\}_{n=1}^N$, where $x_n = \mathbb{R}^d$, where $d \geq 1$ represents the dimension of your data,  and $t_n \in \mathbb{R}$ which are the target values that each data $x_n$ corresponds to.
#
# Next, we seek a prediction function $y$ that takes in $x_n$ and outputs a prediction vector,
# $$
#   y(x) = \textstyle\sum\limits_{i = 1}^d w_i x_i + b.
# $$
#
# Let the squared loss be defined as,
# \begin{equation}
# 	\mathcal{L}(x,t) = \dfrac{1}{2}(y(x) - t)^2, t \in \mathbb{R}
# \end{equation}
# We can then the optimal prediction function by minimizing the mean squared error,
# \begin{equation}
# 		\mathcal{E}(w) = \dfrac{1}{2N}\sum\limits_{n=1}^N \mathcal{L}(x_n, t_n) = \dfrac{1}{2N}\sum\limits_{n=1}^N (w^\top x_n + b - t_n)^2 \tag*{(mse)}
# \end{equation}

# %% [markdown]
# In the following code, you will generate a data set $\mathcal{D}$ consisting of $20$ 1D data points $x_n$ sampled from a uniform distribution along with targets $t_n$ assumed to be given by the formula,
#
# $$
#   t_n = \sin(\pi x_n) + 0.3*\epsilon, \epsilon \sim \mathcal{N}(0,1)
# $$
# Let us visualize these data point using the Matplotlib package.

# %%
n, d = 20, 1 #n represents data points and d represents the number of dimensions

x = random.uniform(key, (n, d), dtype=np.float64,  minval = -5., maxval = 5.)
t = np.sin(np.pi*x) + 0.3*random.normal(key, (n, d))
print(x)
import matplotlib.pyplot as plt

plt.scatter(x, t)
plt.show()
# Out:
# [[-3.3791327 ]
#  [-3.4295106 ]
#  [-0.8759823 ]
#  [-4.1072617 ]
#  [ 2.7118502 ]
#  [-4.8384786 ]
#  [-2.4523294 ]
#  [-0.26344204]
#  [-0.83501434]
#  [-1.3813615 ]
#  [-4.2112675 ]
#  [-4.7401485 ]
#  [ 4.4842796 ]
#  [ 0.9519615 ]
#  [-4.6093464 ]
#  [-2.6214623 ]
#  [ 3.0519714 ]
#  [-0.7612028 ]
#  [ 2.0403442 ]
#  [-1.982131  ]]

# %% [markdown]
# ## 2.1 Directly Solving for $w^\star$ Using the Normal Equation
#
# Since our data set is small, therefore we can directly find the optimal predictor using a bit of linear algebra.
#
# To account for the bias term, it is common to redefining our data and weight as $x_n := \begin{bmatrix} 1 & x_n^\top \end{bmatrix}$ and $w := \begin{bmatrix} b & w^\top \end{bmatrix}$,
# $$
#   y(x_n) = \textstyle\sum\limits_{i = 1}^{d+1} w_i x_{n_i} = w^\top x_n.
# $$
#
# Then, we can show that our mean squared error can be equivalently written as $$\mathcal{E}(w) =    \dfrac{1}{2N} \|Xw-t\|^2_2,$$
# where \begin{equation}
# X = \begin{bmatrix} x_1^\top \\ \vdots \\ x_N^\top \end{bmatrix}  \in \mathbb{R}^{N \times (d+1)} \quad \text{and} \quad t = \begin{bmatrix} t_1\\ \vdots \\ t_N \end{bmatrix} \in \mathbb{R}^N
# \end{equation}
#
# It can be shown that, $$w^\star = (X^\top X)^{-1}X^\top t$$ minimizes the mean-squared error $\mathcal{E}$. This expression is sometimes referred to as the *normal equation*.
#
# **In the space below, build the matrix $X$ and find the optimal solution $w^\star$. Afterwards, plot the optimal prediction function against your dataset.**

# %%
#Bult the X matrix here
X = np.concatenate((np.ones((n, 1)), x),1)
W = [b, w.T]

#Compute w using the normal equation
woptimal = np.dot(np.linalg.inv(np.dot(X.T,X)), np.dot(X.T, t))

#Write your optimal predictor here
y = np.dot( X, woptimal)

#Plot your prediction against data points
plt.scatter(x,t)
plt.plot([np.min(x), np.max(x)], [np.min(x)*woptimal[1]+woptimal[0], np.max(x)*woptimal[1]+woptimal[0]], label = "Decision")
plt.show()

# %% [markdown]
# ## 2.2 Find $w^\star$ Using Gradient Descent
#
# Next, you will use gradient descent to find the solution to the linear regression problem. Recall that the update equation for gradient descent (as studied in class) is given by,
#
# $$w_{k+1} = w_k - \alpha \nabla \mathcal{E}(w_k)$$
#
# $\alpha$ is our learning rate which is usually a small number, e.g., $0.1$
#
# **Implement a jax routine for calculating the gradient of $\mathcal{E}$, and then run the gradient descent algorithm (say, for 100 iterations) until the optimal weight is found.**

# %% [markdown]
# ### 2.2.1 **Define the mse function**
#
# Hint: your code could be similar to how we built the logistic function at the beginning

# %%
# Build the mse function here
def mse(x, t):
  def predicted(w, b):
    return (np.sum(np.power(((np.dot(x, w)+b)-t),2))/2*np.size(x))
  return predicted

# %% [markdown]
# ### 2.2.2 **Implement Gradient Descent and Run for (say, 100) Interations**
#
#
# $$w_{k+1} = w_k - \alpha \nabla \mathcal{E}(w_k)$$
#
# Hint: The function `grad` takes as arguments:
# -  `fun`: the numpy **function** for which the computation of the gradients is needed.
# - `argnums`: the **arguments** of the functions  with respect to which the function will be differentiated
#
# Example:
# ```
# w_gradient, b_gradient = grad(fun = make_mse(x, t), argnums = (0,1))(w,b)
# ```
#
# Then use calculated the gradient in your gradient descent update in a FOR loop
# .

# %%
alpha = 0.0001
iterations = 100
w = w0
b= b0
print(np.shape(w), w,b)
# Update w, b by calculating the gradient and making the update.
import time
stime = time.time()
for i in range(iterations):
  w_gradient, b_gradient = grad(mse(x, t), (0,1))(w,b)
  b = b - alpha*b_gradient
  w = w - alpha*w_gradient

print(w, b, time.time()-stime)
# Out:
# () -1.0517064 -0.6095362
# 0.20175943 -0.020025045 0.7025718688964844

# %% [markdown]
# ### 2.2.3 **Build your optimal linear prediction function and visualize your fit to the data**

# %%
# Your optimal linear prediction function here
w_optimal = np.dot(np.linalg.inv(np.dot(X.T,X)), np.dot(X.T, t))

# Visualize your data and your fit
fig = plt.figure()
plt.plot(x,t, 'o',[np.min(x), np.max(x)], [np.min(x)*w_optimal[1]+w_optimal[0], np.max(x)*w_optimal[1]+w_optimal[0]], '--', [np.min(x), np.max(x)], [np.min(x)*w+b, np.max(x)*w+b], '-')
plt.legend(loc='upper left', labels=['data points', 'Optimal Solution', 'best-fit line'])
fig.suptitle('Linear Regression with Optimal SOlution', fontsize=18)
plt.xlabel('x_data', fontsize=14)
plt.ylabel('y_data', fontsize=14)

plt.show()

# %% [markdown]
# ### 2.2.4 **(Optional) You can use jit to speed calculation.**
#
# **Repeat the gradient descent procedure as before but using jit to speed up the calculation of gradients.**

# %%
# Build your jitted gradient descent iteration here
alpha = 0.0001
iterations = 100
w = w0
b= b0
print(np.shape(w), w,b)
# Update w, b by calculating the gradient and making the update.
import time
stime = time.time()
for i in range(iterations):
  w_gradient, b_gradient = jit(grad(mse(x, t), (0,1)))(w,b)
  b = b - alpha*b_gradient
  w = w - alpha*w_gradient

print(w, b, time.time()-stime)
# Out:
# () -1.0517064 -0.6095362
# 0.20175943 -0.020025045 2.721425771713257

# %% [markdown]
# #3.0 Overfitting and Regularization
#
# The goal of supervised machine learning is to make accurate predictions on data that are not from the training set, also known as the *test set*. However it is not guaranteed that the more data we train on, the better we will perform on the test set.
#
# It could happen that we fit our training set too well, so that a test data that does not look like the training data will cause a large error in our prediction. This is called **overfitting**: the scenario when a predictor that achieves a lower error on the training set results in a large error on the test set.
#
# To overcome overfitting, we can use a technique called regularization, which involves adding a function on to our mean squared error. In the following examples, we will step through several examples of regularization techniques.

# %% [markdown]
# ## 3.1 Building a Dataset
#
# The code below creates a data set of  $n = 100$ examples generated from uniformly from $[-5, 5]$, each example is $5$ dimensional. The targets are assigned as follows, $$t  = x^\top \overline w + 0.1 * \epsilon, \epsilon \sim \mathcal{N}(0,1)$$
# where $\overline w$ is a randomly generated vector with normal distribution.
#
#
# **Your first task is to partition the data into 50 test examples, 20 validation examples and 30 test examples.**

# %%
from sklearn.model_selection import train_test_split
d = 5                             #dimension of your data
n = 100                           #total number of data points
n_train = 50                      #total number of training examples
n_validate = 20                   #total number of examples for validation
n_test = 30                       #total number of examples for testing

x_data = random.uniform(key, (n, d), dtype=np.float64,  minval = -5., maxval = 5.)
true_w = random.normal(key, (d,))
t_data = x_data.dot(true_w) + 0.1 * random.normal(key, (n,))
#Partition into training, validation and test set
x_train, x_test, t_train, t_test = train_test_split(x_data, t_data, test_size=0.5)
x_test, x_val, t_test, t_val = train_test_split(x_test, t_test, test_size=0.3)

# %% [markdown]
# ## 3.2 Solve for $w^\star$ Using Gradient Descent
#
# Next, using the same linear regresion code that you have built above, using gradient descent, compute the optimal predictor $y = x^\top w^\star + b^\star$ corresponding to the mean-squared error
# $$\mathcal{E}(w) = \dfrac{1}{2N}\sum\limits_{n=1}^N (w^\top x_n + b - t_n)^2$$
#
# Afterwards, find the error between the predicted targets on the test set versus the true test targets using the formula,
# $$\|y_\text{test}- t_\text{test}\|_2$$
# where $y_\text{test}$ is your prediction on the test set.

# %%
#Define your mse function here
def mse(x, t):
  def predicted(w, b):
    return (np.sum(np.power(((np.dot(x, w)+b)-t),2))/2*np.size(x[0]))
  return predicted
#Perform gradient descent
alpha = 0.0001
iterations = 100
w = np.arange(5.)*w0
b= b0
print(np.shape(w), w,b)
# Update w, b by calculating the gradient and making the update.
import time
stime = time.time()

print(x_train.shape)
for i in range(iterations):
  w_gradient, b_gradient = grad(mse(x_train, t_train), (0,1))(w,b)
  b = b - alpha*b_gradient
  w = w - alpha*w_gradient
  #error = np.sum(np.power(t_test-(np.dot(x_test, w) + b), 2))
  #print(error)
print(w, b, time.time()-stime)

#Compute and print your test error
error = np.sum(np.power(t_test-(np.dot(x_test, w) + b), 2))
print(error)
# Out:
# (5,) [-0.        -1.0517064 -2.1034129 -3.1551194 -4.2068257] -0.6095362
# (50, 5)
# [ 0.95392054 -0.96496814 -0.11285947  0.37250754  0.17612031] -0.08595443 0.8394920825958252
# 0.5911077

# %% [markdown]
# ## 3.3 $l_2$ regularization
#
# The first regularization technique we will introduce is called $l_2$ regularization.
#
# We define our mean-squared loss function as
# $$\mathcal{E}_{l_2}(w) = \dfrac{1}{2N}\sum\limits_{n=1}^N (w^\top x_n + b - t_n)^2 + \dfrac{\lambda_2}{2}\|w\|^2_2$$
# where $\lambda_2$ is a small positive constant we refer to as the regularization constant, e.g., $r = 0.01$.
#
# This optimization problem is called *ridge regression*.
#
# Make slight changes to your previous code to account for the $l_2$ norm, and using gradient descent, compute the optimal predictor $y = x^\top w^\star + b^\star$ corresponding to this regularized mean-squared error.

# %%
# Build the mse function here
def mse_reg(x, t):
  def predicted(w, b):
    return (np.sum(np.power(((np.dot(x, w)+b)-t),2))/2*np.size(x[0]))+0.001*np.sum(np.power(w, 2))
  return predicted
#Perform gradient descent
alpha = 0.0001
iterations = 100
w = np.arange(5.)*w0
b= b0
print(np.shape(w), w,b)
# Update w, b by calculating the gradient and making the update.
import time
stime = time.time()
print(x_train.shape, t_train.shape)
for i in range(iterations):
  w_gradient, b_gradient = grad(mse_reg(x_train, t_train), (0,1))(w,b)
  b = b - alpha*b_gradient
  w = w - alpha*w_gradient
  #error = np.sum(np.power(t_test-(np.dot(x_test, w) + b), 2))
  #print(error)
print(w, b, time.time()-stime)

#Compute and print your test error
error = np.sum(np.power(t_test-(np.dot(x_test, w) + b), 2))
print(error)
# Out:
# (5,) [-0.        -1.0517064 -2.1034129 -3.1551194 -4.2068257] -0.6095362
# (50, 5) (50,)
# [ 0.95391905 -0.9649671  -0.11285899  0.37250665  0.17612062] -0.085954934 1.0974202156066895
# 0.59110785

# %% [markdown]
# ### 3.3.1 Hyperparameter Tuning Using Validation Set
#
# Next, you are going to tune the regularization parameter $\lambda_2$ using your validation set.
#
# Train several different models for $\lambda_2 \in \{0.1, 0.01, 0.001\}$. Then compute the error between your prediction on the validation set and the corresponding targets using the formula,
# $$\|y_\text{val}- t_\text{val}\|_2$$
#
# Pick the best performing model.

# %%
# Build the mse function here
def mse_reg(x, t, lmb):
  def predicted(w, b):
    return (np.sum(np.power(((np.dot(x, w)+b)-t),2))/2*np.size(x[0]))+lmb*np.sum(np.power(w, 2))
  return predicted
#Perform gradient descent
def gradient(lmb):
  alpha = 0.0001
  iterations = 100
  w = np.arange(5.)*w0
  b= b0
  print(np.shape(w), w,b)
  # Update w, b by calculating the gradient and making the update.
  import time
  stime = time.time()
  #print(x_train.shape, t_train.shape)
  for i in range(iterations):
    w_gradient, b_gradient = grad(mse_reg(x_train, t_train, lmb), (0,1))(w,b)
    b = b - alpha*b_gradient
    w = w - alpha*w_gradient
    #error = np.sum(np.power(t_test-(np.dot(x_test, w) + b), 2))
    #print(error)
  #print(w, b, time.time()-stime)

  #Compute and print your test error
  errortest = np.sum(np.power(t_test-(np.dot(x_test, w) + b), 2))
  print("Test Error", lmb, errortest)
  errorval = np.sum(np.power(t_val-(np.dot(x_val, w) + b), 2))
  print("Validation Error", lmb, errorval)

gradient(0.1)
gradient(0.01)
gradient(0.001)
# Out:
# (5,) [-0.        -1.0517064 -2.1034129 -3.1551194 -4.2068257] -0.6095362
# Test Error 0.1 0.59109306
# Validation Error 0.1 0.23871127
# (5,) [-0.        -1.0517064 -2.1034129 -3.1551194 -4.2068257] -0.6095362
# Test Error 0.01 0.5911052
# Validation Error 0.01 0.2390997
# (5,) [-0.        -1.0517064 -2.1034129 -3.1551194 -4.2068257] -0.6095362
# Test Error 0.001 0.59110785
# Validation Error 0.001 0.23913911

# %%
### the highest lambda 0.1 gives the least error for validation test

# %% [markdown]
# ### 3.3.2 Compute Test Error
#
# Finally, using the best performing model, find the error between the predicted targets on the test set versus the true test targets using the formula,
# $$\|y_\text{test}- t_\text{test}\|_2$$
# where $y_\text{test}$ is your prediction on the test set.

# %%
# Your code Here
gradient(0.1)
# Out:
# (5,) [-0.        -1.0517064 -2.1034129 -3.1551194 -4.2068257] -0.6095362
# Test Error 0.1 0.59109306
# Validation Error 0.1 0.23871127

# %% [markdown]
# ## 3.4 $l_1$ Regularization
#
# The next regularization technique we will introduce is called $l_1$ regularization.
#
# We define our mean-squared loss function as
# $$\mathcal{E}_{l_1}(w) = \dfrac{1}{2N}\sum\limits_{n=1}^N (w^\top x_n + b - t_n)^2 + \dfrac{\lambda_1}{2}\|w\|_1$$
# where $\lambda_1$ is again our regularization constant.
#
# This optimization problem is called the *LASSO*.
#
# **Repeat the previous experiment by training several different models and choosing the best one based on its performance on the validation set.**
#
# **Finally, pick the best performing model and use it to find the error between the predicted targets on the test set versus the true test targets.**

# %%
def mse_reg(x, t, lmb):
  def predicted(w, b):
    return (np.sum(np.power(((np.dot(x, w)+b)-t),2))/2*np.size(x[0]))+lmb*np.sum(np.abs(w))
  return predicted
#Perform gradient descent
def gradientl1(lmb):
  alpha = 0.0001
  iterations = 100
  w = np.arange(5.)*w0
  b= b0
  print(np.shape(w), w,b)
  # Update w, b by calculating the gradient and making the update.
  import time
  stime = time.time()
  #print(x_train.shape, t_train.shape)
  for i in range(iterations):
    w_gradient, b_gradient = grad(mse_reg(x_train, t_train, lmb), (0,1))(w,b)
    b = b - alpha*b_gradient
    w = w - alpha*w_gradient
    #error = np.sum(np.power(t_test-(np.dot(x_test, w) + b), 2))
    #print(error)
  #print(w, b, time.time()-stime)

  #Compute and print your test error
  errortest = np.sum(np.power(t_test-(np.dot(x_test, w) + b), 2))
  print("Test Error", lmb, errortest)
  errorval = np.sum(np.power(t_val-(np.dot(x_val, w) + b), 2))
  print("Validation Error", lmb, errorval)

gradientl1(0.1)
gradientl1(0.01)
gradientl1(0.001)
# Out:
# (5,) [-0.        -1.0517064 -2.1034129 -3.1551194 -4.2068257] -0.6095362
# Test Error 0.1 0.59129006
# Validation Error 0.1 0.23902324
# (5,) [-0.        -1.0517064 -2.1034129 -3.1551194 -4.2068257] -0.6095362
# Test Error 0.01 0.5911252
# Validation Error 0.01 0.23913072
# (5,) [-0.        -1.0517064 -2.1034129 -3.1551194 -4.2068257] -0.6095362
# Test Error 0.001 0.59110785
# Validation Error 0.001 0.23914173

# %%
## difference in error in the fourth digit

# %% [markdown]
# ## 3.5 Approximate $l_1$ Regularization
#
# A technicality is that the  $l_1$ norm is not differentiable, so JAX was actually avoiding the non-differentiable points.
#
# To address the non-differentiability of $l_1$ norm, Schmidt *et al.* [1] proposed a differentiable approximation to the $l_1$ norm.
#
# In this case, we define our mean-squared loss function as
# $$\mathcal{E}_{\widetilde{l_1}}(w) = \dfrac{1}{2N}\sum\limits_{n=1}^N (w^\top x_n + b - t_n)^2 + \sum\limits_{i = 1}^d \dfrac{\lambda}{a} (\log(1+\exp(a w_i)) + \log(1-\exp(-a w_i)))$$
# where both $a$ and $\lambda$ are regularization constants.
#
#
# **Repeat the previous experiments by training several different models and choosing the best one based on its performance on the validation set.**
#
# (For convenience, you can fix $a$, say $a = 0.1$. Alternatively you can tune both $a$ and $\lambda$)
#
# **Finally, pick the best performing model and use it to find the error between the predicted targets on the test set versus the true test targets.**
#
# [1] *Mark Schmidt, Glenn Fung, and Rmer Rosales. Fast
# optimization methods for l1 regularization: A comparative study and two new approaches. In European Conference on Machine Learning, pages 286–297.
# Springer, 2007.*

# %%
def mse_reg(x, t, lmb):
  def predicted(w, b):
    k1=np.log(1+np.exp(0.1*w))
    k2=np.log(1-np.exp(-0.1*w))
    l1 = np.sum(lmb/0.1*((np.log(1+np.exp(0.1*w)))+(np.log(1-np.exp(-0.1*w)))))
    print(k1, k2, l1)
    return (np.sum(np.power(((np.dot(x, w)+b)-t),2))/2*np.size(x[0]))+l1
  return predicted
#Perform gradient descent
def gradientl1S(lmb):
  alpha = 0.0001
  iterations = 100
  w = np.arange(5.)*w0+1
  b= b0
  print(np.shape(w), w,b)
  # Update w, b by calculating the gradient and making the update.
  import time
  stime = time.time()
  #print(x_train.shape, t_train.shape)
  for i in range(iterations):
    w_gradient, b_gradient = grad(mse_reg(x_train, t_train, lmb), (0,1))(w,b)
    b = b - alpha*b_gradient
    w = w - alpha*w_gradient
    #error = np.sum(np.power(t_test-(np.dot(x_test, w) + b), 2))
    #print(error)
  print(w, b, time.time()-stime)

  #Compute and print your test error
  errortest = np.sum(np.power(t_test-(np.dot(x_test, w) + b), 2))
  print("Test Error", lmb, errortest)
  errorval = np.sum(np.power(t_val-(np.dot(x_val, w) + b), 2))
  print("Validation Error", lmb, errorval)

gradientl1S(0.1)
gradientl1S(0.01)
gradientl1S(0.001)
# Out:
# (5,) [ 1.         -0.05170643 -1.1034129  -2.1551194  -3.2068257 ] -0.6095362
# Traced<ConcreteArray([0.7443967  0.69056517 0.63949764 0.5911857  0.54560584])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7443967 , 0.69056517, 0.63949764, 0.5911857 , 0.54560584],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.352168       nan       nan       nan       nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.352168,       nan,       nan,       nan,       nan], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.754879   0.6836429  0.64804214 0.60677475 0.573671  ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.754879  , 0.6836429 , 0.64804214, 0.60677475, 0.573671  ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.1806567        nan        nan        nan        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.1806567,        nan,        nan,        nan,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.76122516 0.6781356  0.6542144  0.62091005 0.5964337 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.76122516, 0.6781356 , 0.6542144 , 0.62091005, 0.5964337 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.091538       nan       nan       nan       nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.091538,       nan,       nan,       nan,       nan], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7647315  0.67370135 0.6587987  0.6335402  0.61486995])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7647315 , 0.67370135, 0.6587987 , 0.6335402 , 0.61486995],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.0461116        nan        nan        nan        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.0461116,        nan,        nan,        nan,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7663193  0.67006063 0.66231924 0.64469653 0.6298084 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7663193 , 0.67006063, 0.66231924, 0.64469653, 0.6298084 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.0263376        nan        nan        nan        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.0263376,        nan,        nan,        nan,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7666351  0.6670182  0.66512257 0.654463   0.6419327 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7666351 , 0.6670182 , 0.66512257, 0.654463  , 0.6419327 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.02246      nan      nan      nan      nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.02246,      nan,      nan,      nan,      nan], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.766129  0.6644379 0.6674354 0.6629526 0.6517971])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.766129 , 0.6644379, 0.6674354, 0.6629526, 0.6517971], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.0286813        nan        nan        nan        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.0286813,        nan,        nan,        nan,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7651116 0.6622232 0.669405  0.6702916 0.6598471])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7651116, 0.6622232, 0.669405 , 0.6702916, 0.6598471], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.0413342        nan        nan        nan        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.0413342,        nan,        nan,        nan,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.76379514 0.660305   0.6711259  0.6766087  0.66643894])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.76379514, 0.660305  , 0.6711259 , 0.6766087 , 0.66643894],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.0579994        nan        nan        nan        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.0579994,        nan,        nan,        nan,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.76232404 0.65863246 0.672659   0.6820285  0.67185706])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.76232404, 0.65863246, 0.672659  , 0.6820285 , 0.67185706],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.0770311        nan        nan        nan        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.0770311,        nan,        nan,        nan,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7607944  0.657167   0.67404306 0.6866688  0.67632806])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7607944 , 0.657167  , 0.67404306, 0.6866688 , 0.67632806],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.0972939        nan        nan        nan        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.0972939,        nan,        nan,        nan,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7592699  0.6558786  0.67530364 0.6906422  0.6800333 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7592699 , 0.6558786 , 0.67530364, 0.6906422 , 0.6800333 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.117995       nan       nan       nan       nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.117995,       nan,       nan,       nan,       nan], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.75779104 0.65474313 0.6764574  0.69408554 0.6831179 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.75779104, 0.65474313, 0.6764574 , 0.69408554, 0.6831179 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.1385798        nan        nan -6.2796326        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.1385798,        nan,        nan, -6.2796326,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7563839  0.6537385  0.6775165  0.6966432  0.68569946])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7563839 , 0.6537385 , 0.6775165 , 0.6966432 , 0.68569946],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.1586485        nan        nan -4.9681964        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.1586485,        nan,        nan, -4.9681964,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.75505203 0.65286875 0.67848474 0.69901717 0.6878675 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.75505203, 0.65286875, 0.67848474, 0.69901717, 0.6878675 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.1780972        nan        nan -4.453527         nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.1780972,        nan,        nan, -4.453527 ,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7538104  0.6521036  0.6793729  0.70105964 0.68970567])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7538104 , 0.6521036 , 0.6793729 , 0.70105964, 0.68970567],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.1966417        nan        nan -4.1579566        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.1966417,        nan,        nan, -4.1579566,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7526616  0.65142953 0.6801869  0.7028012  0.69128424])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7526616 , 0.65142953, 0.6801869 , 0.7028012 , 0.69128424],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.214171         nan        nan -3.9616177        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.214171 ,        nan,        nan, -3.9616177,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7516031  0.6508359  0.68093187 0.704281   0.69268453])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7516031 , 0.6508359 , 0.68093187, 0.704281  , 0.69268453],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.2306476        nan        nan -3.8211925        nan])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.2306476,        nan,        nan, -3.8211925,        nan],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7506292 0.6503147 0.6816125 0.7055368 0.6942807])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7506292, 0.6503147, 0.6816125, 0.7055368, 0.6942807], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.2460973        nan        nan -3.7161765 -6.090902 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.2460973,        nan,        nan, -3.7161765, -6.090902 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7497128  0.64986825 0.68223387 0.7066059  0.69486016])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7497128 , 0.64986825, 0.68223387, 0.7066059 , 0.69486016],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.2608929        nan        nan -3.634984  -5.6789007])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.2608929,        nan,        nan, -3.634984 , -5.6789007],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7489045  0.64946246 0.682801   0.7075035  0.6954573 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7489045 , 0.64946246, 0.682801  , 0.7075035 , 0.6954573 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.2741601        nan        nan -3.5717413 -5.380769 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.2741601,        nan,        nan, -3.5717413, -5.380769 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74818385 0.64909893 0.6833158  0.70825905 0.69602466])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74818385, 0.64909893, 0.6833158 , 0.70825905, 0.69602466],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.2861645        nan        nan -3.5215662 -5.161982 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.2861645,        nan,        nan, -3.5215662, -5.161982 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74753785 0.64877605 0.68378145 0.7088956  0.6965465 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74753785, 0.64877605, 0.68378145, 0.7088956 , 0.6965465 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.2970712        nan        nan -3.4812381 -4.9961505])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.2970712,        nan,        nan, -3.4812381, -4.9961505],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7469569  0.64849067 0.68420166 0.7094322  0.697019  ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7469569 , 0.64849067, 0.68420166, 0.7094322 , 0.697019  ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3069987        nan        nan -3.4485166 -4.8666787])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3069987,        nan,        nan, -3.4485166, -4.8666787],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7464335 0.6482393 0.6845802 0.7098847 0.697444 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7464335, 0.6482393, 0.6845802, 0.7098847, 0.697444 ], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.316042         nan        nan -3.4217756 -4.763137 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.316042 ,        nan,        nan, -3.4217756, -4.763137 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7459618 0.6480184 0.6849208 0.7102659 0.6978252])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7459618, 0.6480184, 0.6849208, 0.7102659, 0.6978252], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3242767        nan        nan -3.3998153 -4.678742 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3242767,        nan,        nan, -3.3998153, -4.678742 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74553615 0.6478245  0.685227   0.71058667 0.6981664 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74553615, 0.6478245 , 0.685227  , 0.71058667, 0.6981664 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3317726        nan        nan -3.3817146 -4.608844 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3317726,        nan,        nan, -3.3817146, -4.608844 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74515235 0.6476544  0.685502   0.71085656 0.6984719 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74515235, 0.6476544 , 0.685502  , 0.71085656, 0.6984719 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3385894        nan        nan -3.3667545 -4.5502048])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3385894,        nan,        nan, -3.3667545, -4.5502048],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7448061  0.6475053  0.68574893 0.71108323 0.6987458 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7448061 , 0.6475053 , 0.68574893, 0.71108323, 0.6987458 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3447843        nan        nan -3.354372  -4.5004563])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3447843,        nan,        nan, -3.354372 , -4.5004563],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74449396 0.64737445 0.6859705  0.71127313 0.6989916 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74449396, 0.64737445, 0.6859705 , 0.71127313, 0.6989916 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3504083        nan        nan -3.3441184 -4.457859 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3504083,        nan,        nan, -3.3441184, -4.457859 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7442125  0.64725953 0.6861692  0.71143186 0.6992125 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7442125 , 0.64725953, 0.6861692 , 0.71143186, 0.6992125 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3555095        nan        nan -3.3356287 -4.421075 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3555095,        nan,        nan, -3.3356287, -4.421075 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74395895 0.6471586  0.68634737 0.71156436 0.6994115 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74395895, 0.6471586 , 0.68634737, 0.71156436, 0.6994115 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3601322        nan        nan -3.328605  -4.3890905])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3601322,        nan,        nan, -3.328605 , -4.3890905],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74373066 0.6470698  0.68650705 0.7116744  0.6995911 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74373066, 0.6470698 , 0.68650705, 0.7116744 , 0.6995911 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3643174        nan        nan -3.322805  -4.361091 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3643174,        nan,        nan, -3.322805 , -4.361091 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7435249  0.6469916  0.68665    0.71176565 0.6997536 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7435249 , 0.6469916 , 0.68665   , 0.71176565, 0.6997536 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3681026        nan        nan -3.3180282 -4.3364387])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3681026,        nan,        nan, -3.3180282, -4.3364387],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7433398  0.6469225  0.68677795 0.71184075 0.6999008 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7433398 , 0.6469225 , 0.68677795, 0.71184075, 0.6999008 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3715234        nan        nan -3.3141084 -4.3146143])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3715234,        nan,        nan, -3.3141084, -4.3146143],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74317336 0.6468613  0.68689257 0.71190256 0.70003444])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74317336, 0.6468613 , 0.68689257, 0.71190256, 0.70003444],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3746126        nan        nan -3.3109043 -4.2952127])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3746126,        nan,        nan, -3.3109043, -4.2952127],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7430237  0.646807   0.686995   0.71195275 0.70015615])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7430237 , 0.646807  , 0.686995  , 0.71195275, 0.70015615],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3773997        nan        nan -3.3083034 -4.277872 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3773997,        nan,        nan, -3.3083034, -4.277872 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74288917 0.64675874 0.68708676 0.7119932  0.7002672 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74288917, 0.64675874, 0.68708676, 0.7119932 , 0.7002672 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3799124        nan        nan -3.30621   -4.262324 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3799124,        nan,        nan, -3.30621  , -4.262324 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7427682  0.64671564 0.6871686  0.7120256  0.7003686 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7427682 , 0.64671564, 0.6871686 , 0.7120256 , 0.7003686 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3821754        nan        nan -3.3045382 -4.2483263])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3821754,        nan,        nan, -3.3045382, -4.2483263],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7426598 0.646677  0.6872417 0.7120512 0.7004615])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7426598, 0.646677 , 0.6872417, 0.7120512, 0.7004615], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3842118        nan        nan -3.3032224 -4.235675 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3842118,        nan,        nan, -3.3032224, -4.235675 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7425624 0.6466423 0.687307  0.712071  0.700547 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7425624, 0.6466423, 0.687307 , 0.712071 , 0.700547 ], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.386043         nan        nan -3.3022048 -4.224203 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.386043 ,        nan,        nan, -3.3022048, -4.224203 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7424751  0.646611   0.68736523 0.71208596 0.7006253 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7424751 , 0.646611  , 0.68736523, 0.71208596, 0.7006253 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3876882        nan        nan -3.301436  -4.213776 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3876882,        nan,        nan, -3.301436 , -4.213776 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.742397  0.6465825 0.6874171 0.712097  0.7006977])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.742397 , 0.6465825, 0.6874171, 0.712097 , 0.7006977], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3891652        nan        nan -3.3008761 -4.204254 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3891652,        nan,        nan, -3.3008761, -4.204254 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.742327   0.6465567  0.6874634  0.71210444 0.7007644 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.742327  , 0.6465567 , 0.6874634 , 0.71210444, 0.7007644 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3904886        nan        nan -3.3004897 -4.1955504])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3904886,        nan,        nan, -3.3004897, -4.1955504],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74226433 0.646533   0.6875045  0.71210915 0.7008263 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74226433, 0.646533  , 0.6875045 , 0.71210915, 0.7008263 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3916752        nan        nan -3.3002455 -4.187557 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3916752,        nan,        nan, -3.3002455, -4.187557 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74220836 0.6465113  0.68754107 0.7121116  0.7008837 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74220836, 0.6465113 , 0.68754107, 0.7121116 , 0.7008837 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3927364        nan        nan -3.3001227 -4.180212 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3927364,        nan,        nan, -3.3001227, -4.180212 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7421584  0.64649135 0.68757355 0.71211207 0.7009368 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7421584 , 0.64649135, 0.68757355, 0.71211207, 0.7009368 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3936846        nan        nan -3.3001    -4.1734347])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3936846,        nan,        nan, -3.3001   , -4.1734347],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74211395 0.6464728  0.68760234 0.7121109  0.7009863 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74211395, 0.6464728 , 0.68760234, 0.7121109 , 0.7009863 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3945312        nan        nan -3.3001583 -4.1671724])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3945312,        nan,        nan, -3.3001583, -4.1671724],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7420742  0.6464556  0.68762785 0.71210843 0.70103246])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7420742 , 0.6464556 , 0.68762785, 0.71210843, 0.70103246],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.395286         nan        nan -3.3002827 -4.161373 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.395286 ,        nan,        nan, -3.3002827, -4.161373 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.742039   0.64643943 0.6876504  0.71210504 0.7010755 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.742039  , 0.64643943, 0.6876504 , 0.71210504, 0.7010755 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3959575        nan        nan -3.3004606 -4.1559844])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3959575,        nan,        nan, -3.3004606, -4.1559844],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7420077  0.64642435 0.6876703  0.7121007  0.70111597])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7420077 , 0.64642435, 0.6876703 , 0.7121007 , 0.70111597],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3965538        nan        nan -3.300682  -4.1509724])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3965538,        nan,        nan, -3.300682 , -4.1509724],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7419799  0.6464101  0.68768775 0.7120958  0.7011537 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7419799 , 0.6464101 , 0.68768775, 0.7120958 , 0.7011537 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3970828        nan        nan -3.3009377 -4.146294 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3970828,        nan,        nan, -3.3009377, -4.146294 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74195534 0.64639664 0.68770325 0.7120902  0.7011893 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74195534, 0.64639664, 0.68770325, 0.7120902 , 0.7011893 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3975515        nan        nan -3.3012223 -4.1419187])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3975515,        nan,        nan, -3.3012223, -4.1419187],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74193364 0.6463839  0.6877167  0.71208435 0.7012226 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74193364, 0.6463839 , 0.6877167 , 0.71208435, 0.7012226 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3979645        nan        nan -3.3015249 -4.137828 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3979645,        nan,        nan, -3.3015249, -4.137828 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7419146  0.64637166 0.6877285  0.71207803 0.70125407])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7419146 , 0.64637166, 0.6877285 , 0.71207803, 0.70125407],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3983278        nan        nan -3.301847  -4.133984 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3983278,        nan,        nan, -3.301847 , -4.133984 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7418979  0.6463601  0.68773884 0.7120716  0.70128363])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7418979 , 0.6463601 , 0.68773884, 0.7120716 , 0.70128363],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3986478        nan        nan -3.3021774 -4.130378 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3986478,        nan,        nan, -3.3021774, -4.130378 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7418833  0.6463491  0.68774784 0.7120649  0.70131177])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7418833 , 0.6463491 , 0.68774784, 0.7120649 , 0.70131177],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3989275        nan        nan -3.3025174 -4.1269727])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3989275,        nan,        nan, -3.3025174, -4.1269727],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7418705  0.6463383  0.6877555  0.71205825 0.7013383 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7418705 , 0.6463383 , 0.6877555 , 0.71205825, 0.7013383 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3991709        nan        nan -3.302861  -4.1237707])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3991709,        nan,        nan, -3.302861 , -4.1237707],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74185956 0.6463281  0.6877621  0.7120516  0.70136356])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74185956, 0.6463281 , 0.6877621 , 0.7120516 , 0.70136356],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3993816        nan        nan -3.3032079 -4.1207366])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3993816,        nan,        nan, -3.3032079, -4.1207366],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74185    0.6463182  0.6877678  0.7120448  0.70138747])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74185   , 0.6463182 , 0.6877678 , 0.7120448 , 0.70138747],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3995636        nan        nan -3.3035564 -4.117866 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3995636,        nan,        nan, -3.3035564, -4.117866 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7418419  0.64630866 0.6877725  0.712038   0.7014102 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7418419 , 0.64630866, 0.6877725 , 0.712038  , 0.7014102 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3997192        nan        nan -3.3039005 -4.115145 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3997192,        nan,        nan, -3.3039005, -4.115145 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7418349  0.6462994  0.68777657 0.71203136 0.7014318 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7418349 , 0.6462994 , 0.68777657, 0.71203136, 0.7014318 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3998528        nan        nan -3.3042445 -4.11256  ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3998528,        nan,        nan, -3.3042445, -4.11256  ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.741829  0.6462905 0.6877799 0.7120247 0.7014525])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.741829 , 0.6462905, 0.6877799, 0.7120247, 0.7014525], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.399965         nan        nan -3.3045852 -4.1101046])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.399965 ,        nan,        nan, -3.3045852, -4.1101046],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7418242 0.6462817 0.6877826 0.7120184 0.7014721])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7418242, 0.6462817, 0.6877826, 0.7120184, 0.7014721], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.4000576        nan        nan -3.3049197 -4.1077676])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.4000576,        nan,        nan, -3.3049197, -4.1077676],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
# ...
# Traced<ConcreteArray([0.7419297  0.64615923 0.6875545  0.71201694 0.7018274 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7419297 , 0.64615923, 0.6875545 , 0.71201694, 0.7018274 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3980412        nan        nan -3.3049865 -4.0664988])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3980412,        nan,        nan, -3.3049865, -4.0664988],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74193186 0.6461535  0.687553   0.7120125  0.7018376 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74193186, 0.6461535 , 0.687553  , 0.7120125 , 0.7018376 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3979998        nan        nan -3.3052123 -4.065341 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3979998,        nan,        nan, -3.3052123, -4.065341 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7419341 0.6461479 0.6875515 0.7120083 0.7018475])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7419341, 0.6461479, 0.6875515, 0.7120083, 0.7018475], dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.397956         nan        nan -3.3054314 -4.0642195])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.397956 ,        nan,        nan, -3.3054314, -4.0642195],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7419364  0.64614236 0.68754995 0.71200407 0.701857  ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7419364 , 0.64614236, 0.68754995, 0.71200407, 0.701857  ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.397912         nan        nan -3.305646  -4.0631375])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.397912 ,        nan,        nan, -3.305646 , -4.0631375],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7419389  0.646137   0.6875484  0.71200013 0.70186627])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7419389 , 0.646137  , 0.6875484 , 0.71200013, 0.70186627],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3978667        nan        nan -3.305854  -4.062084 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3978667,        nan,        nan, -3.305854 , -4.062084 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74194115 0.64613175 0.68754673 0.71199614 0.7018754 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74194115, 0.64613175, 0.68754673, 0.71199614, 0.7018754 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3978214        nan        nan -3.306059  -4.0610633])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3978214,        nan,        nan, -3.306059 , -4.0610633],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74194366 0.6461266  0.6875451  0.7119924  0.70188415])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74194366, 0.6461266 , 0.6875451 , 0.7119924 , 0.70188415],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.397775         nan        nan -3.3062556 -4.0600677])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.397775 ,        nan,        nan, -3.3062556, -4.0600677],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74194616 0.64612156 0.6875436  0.7119886  0.7018927 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74194616, 0.64612156, 0.6875436 , 0.7119886 , 0.7018927 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3977277        nan        nan -3.3064492 -4.059104 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3977277,        nan,        nan, -3.3064492, -4.059104 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74194854 0.6461167  0.68754196 0.7119849  0.7019009 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74194854, 0.6461167 , 0.68754196, 0.7119849 , 0.7019009 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3976812        nan        nan -3.3066378 -4.0581684])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3976812,        nan,        nan, -3.3066378, -4.0581684],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74195105 0.6461119  0.68754035 0.7119814  0.70190907])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74195105, 0.6461119 , 0.68754035, 0.7119814 , 0.70190907],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.397634         nan        nan -3.3068202 -4.0572586])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.397634 ,        nan,        nan, -3.3068202, -4.0572586],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74195343 0.6461072  0.6875388  0.7119779  0.701917  ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74195343, 0.6461072 , 0.6875388 , 0.7119779 , 0.701917  ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3975875        nan        nan -3.3070006 -4.05637  ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3975875,        nan,        nan, -3.3070006, -4.05637  ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74195594 0.6461026  0.6875372  0.7119746  0.70192456])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74195594, 0.6461026 , 0.6875372 , 0.7119746 , 0.70192456],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3975403        nan        nan -3.307175  -4.0555096])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3975403,        nan,        nan, -3.307175 , -4.0555096],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74195844 0.64609814 0.6875355  0.7119712  0.70193213])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74195844, 0.64609814, 0.6875355 , 0.7119712 , 0.70193213],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3974943        nan        nan -3.3073473 -4.0546703])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3974943,        nan,        nan, -3.3073473, -4.0546703],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7419608  0.6460937  0.687534   0.71196806 0.70193934])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7419608 , 0.6460937 , 0.687534  , 0.71196806, 0.70193934],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.397447         nan        nan -3.3075118 -4.053856 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.397447 ,        nan,        nan, -3.3075118, -4.053856 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7419632  0.64608943 0.6875325  0.7119648  0.70194644])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7419632 , 0.64608943, 0.6875325 , 0.7119648 , 0.70194644],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.397402         nan        nan -3.3076746 -4.0530596])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.397402 ,        nan,        nan, -3.3076746, -4.0530596],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7419656  0.64608526 0.68753093 0.71196175 0.7019534 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7419656 , 0.64608526, 0.68753093, 0.71196175, 0.7019534 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.397356         nan        nan -3.3078341 -4.0522842])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.397356 ,        nan,        nan, -3.3078341, -4.0522842],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.741968   0.6460812  0.68752944 0.7119588  0.70196   ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.741968  , 0.6460812 , 0.68752944, 0.7119588 , 0.70196   ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.397311         nan        nan -3.3079891 -4.0515337])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.397311 ,        nan,        nan, -3.3079891, -4.0515337],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74197024 0.6460772  0.68752795 0.7119559  0.70196664])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74197024, 0.6460772 , 0.68752795, 0.7119559 , 0.70196664],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3972664        nan        nan -3.3081388 -4.050801 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3972664,        nan,        nan, -3.3081388, -4.050801 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7419726  0.64607334 0.68752646 0.7119531  0.701973  ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7419726 , 0.64607334, 0.68752646, 0.7119531 , 0.701973  ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3972225        nan        nan -3.3082871 -4.0500817])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3972225,        nan,        nan, -3.3082871, -4.0500817],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.7419748  0.64606947 0.687525   0.71195024 0.70197916])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.7419748 , 0.64606947, 0.687525  , 0.71195024, 0.70197916],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3971798        nan        nan -3.3084307 -4.0493875])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3971798,        nan,        nan, -3.3084307, -4.0493875],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# Traced<ConcreteArray([0.74197704 0.6460658  0.6875236  0.71194756 0.7019853 ])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([0.74197704, 0.6460658 , 0.6875236 , 0.71194756, 0.7019853 ],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray([-2.3971367        nan        nan -3.3085692 -4.0487075])>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray([-2.3971367,        nan,        nan, -3.3085692, -4.0487075],            dtype=float32)
#        tangent = Traced<ShapedArray(float32[5]):JaxprTrace(level=2/0)> Traced<ConcreteArray(nan)>with<JVPTrace(level=3/0)>
#   with primal = DeviceArray(nan, dtype=float32)
#        tangent = Traced<ShapedArray(float32[]):JaxprTrace(level=2/0)>
# [ 0.95390266 -0.9649719  -0.11281733  0.3724862   0.17610566] -0.08582695 2.0319178104400635
# Test Error 0.001 0.5904647
# Validation Error 0.001 0.23891112

# %%
# Your code here
# Out:
# nan

# %% [markdown]
# ## 3.6 Elastic Net
#
# Finally, we can define our mean-squared loss function as a combination of $l_1$ and $l_2$ norm,
# $$\mathcal{E}_{l_1+l_2}(w) = \dfrac{1}{2N}\sum\limits_{n=1}^N (w^\top x_n + b - t_n)^2 + \frac{r_1}{2}\|w\|_1 + \dfrac{r_2}{2}\|w\|_2^2$$
#
# This regularizer is called the elastic net.
#
# **Repeat the previous experiments by training several different models and choosing the best one based on its performance on the validation set.**
#
# **Finally, pick the best performing model and use it to find the error between the predicted targets on the test set versus the true test targets.**

# %%
# Your code here:
def mse_reg(x, t, lmb):
  def predicted(w, b):
    return ((np.sum(np.power(((np.dot(x, w)+b)-t),2))/2*np.size(x[0]))+lmb*np.sum(np.abs(w))+lmb*np.sum(np.power(w,2)))
  return predicted
#Perform gradient descent
def gradientl1l2(lmb):
  alpha = 0.0001
  iterations = 100
  w = np.arange(5.)*w0
  b= b0
  print(np.shape(w), w,b)
  # Update w, b by calculating the gradient and making the update.
  import time
  stime = time.time()
  #print(x_train.shape, t_train.shape)
  for i in range(iterations):
    w_gradient, b_gradient = grad(mse_reg(x_train, t_train, lmb), (0,1))(w,b)
    b = b - alpha*b_gradient
    w = w - alpha*w_gradient
    #error = np.sum(np.power(t_test-(np.dot(x_test, w) + b), 2))
    #print(error)
  #print(w, b, time.time()-stime)

  #Compute and print your error
  errortrain = np.sum(np.power(t_train-(np.dot(x_train, w) + b), 2))
  print("Train Error", lmb, errortrain)
  errortest = np.sum(np.power(t_test-(np.dot(x_test, w) + b), 2))
  print("Test Error", lmb, errortest)
  errorval = np.sum(np.power(t_val-(np.dot(x_val, w) + b), 2))
  print("Validation Error", lmb, errorval)

gradientl1l2(0.1)
gradientl1l2(0.01)
gradientl1l2(0.5)
# Out:
# (5,) [-0.        -1.0517064 -2.1034129 -3.1551194 -4.2068257] -0.6095362
# Train Error 0.1 0.68429077
# Test Error 0.1 0.59129024
# Validation Error 0.1 0.2385969
# (5,) [-0.        -1.0517064 -2.1034129 -3.1551194 -4.2068257] -0.6095362
# Train Error 0.01 0.68365
# Test Error 0.01 0.5911225
# Validation Error 0.01 0.23908725
# (5,) [-0.        -1.0517064 -2.1034129 -3.1551194 -4.2068257] -0.6095362
# Train Error 0.5 0.68776286
# Test Error 0.5 0.59264
# Validation Error 0.5 0.23665339

# %% [markdown]
# ## 3.7 Report what you find
#
# How does the weight and bias compare under each regularization scheme? Which regularizer does the best on the test set?

# %% [markdown]
# Report your finding here:

# %%
# With both the l1 and l2 regularization, the training error was higher while the validation error was lowest for validation dataset.
# The least error was for highest lambda of 0.1. On further increasing the lambda, while error reduced for validation set, it increased for test and training set.
